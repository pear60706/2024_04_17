# %%
# 比較運算子
5 > 3
5 < 3
5 >= 5
# Out:
# True

# %%
5 == 5
5 != 5
# Out:
# False

# %%
age:int = 20
if age >= 18:#         if後面bool值
    print('此人大於18歲')
    print('可以考駕照')
    print('有投票')
print('程式結束')
# Out:
# 程式結束

# %%
age:int = 17
if age >= 18:
    print('此人大於18歲')
    print('可以考駕照')
    print('有投票')
print('程式結束')
